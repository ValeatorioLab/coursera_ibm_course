# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, we will explore some of the key tools within the Data Science ecosystem.

# %% [markdown]
# **Objectives:**
# - List some popular languages for Data Science
# - List some popular libraries used by Data Science
# - Show what a table looks like using Markdown
# - Show some examples of simple math code in Python

# %% [markdown]
# Programming is a must-have skill for any Data Scientist. Some of the most commonly used languages include:
# 1. Python
# 2. R
# 3. SQL
# 4. Java
# 5. Julia

# %% [markdown]
# Each language has its own libraries used by Data Scientists. Some of the most important ones include:
# 1. Panda (Python - data manipulation)
# 2. ggplot (R - high-level graphs)
# 3. Scikit-learn (Python - Machine Learning)
# 4. Seaborn (Python - advanced data visualization)

# %% [markdown]
# The following table shows three open-source development environment tools used in data science:
# | Data Science Tools |
# | ------------------ |
# | Jupyter            |
# | RStudio            |
# | Spyder             |

# %% [markdown]
# ### Next, we'll explore how arithmetic expressions are evaluated in Python. Let's look at some examples:

# %%
# This is a simple arithmetic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This expression convert 200 minutes to hours
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Valerio Lapiello
